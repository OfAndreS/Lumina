# %% [markdown]
# ---
#
# #### **Referências ) - HMDA**
#
# - [Download do Dataset](https://www.consumerfinance.gov/data-research/hmda/historic-data/?geo=nationwide&records=all-records&field_descriptions=labels)
#
# ---

# %%
import pandas as pd

# %%
# D04 - HDMA 
df_d04 = pd.read_csv("raw/HMDA.csv")
df_d04.head()
