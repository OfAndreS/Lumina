# %% [markdown]
# ---
#
# #### **Intro ) - Referências**
#
# - [Download do Dataset](https://www.openml.org/search?type=data&sort=version&status=any&order=asc&exact_name=ACSIncome&id=43136)
# - [Tradução das colunas](https://github.com/socialfoundations/folktables)
#
# ---
